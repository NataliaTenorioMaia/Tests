# %% [markdown]
# # Testing Model in Production
#
# In this notebook, we will load the trained classifiers and vectorizer and use them to predict the appeal scores of new videos on Youtube. This will give us a better idea on how well the classifiers, or ensemble of classifers, are telling us which of the most recent videos on Youtube, related to artificial intelligence, machine learning and deep learning, are more likely to insterest me.
#
# If I am satisfied with the predictions of the classifiers, we will select the predictor that performs the best and use it in the web application that will be built next.

# %%
import pandas as pd
import joblib as jb
from scipy.sparse import hstack, csr_matrix
import numpy as np
import json
import youtube_dl

# %% [markdown]
# ## Importing trained models

# %%
# Trained models:
clf_rf = jb.load("random_forest_2021.pkl.z")
clf_lr = jb.load("logistic_reg_2021.pkl.z")
clf_lgbm = jb.load("lgbm_2021.pkl.z")
# Trained vectorizer:
title_vec = jb.load("title_vectorizer_2021.pkl.z")

# %% [markdown]
# ## Extracting and cleaning new data

# %%
# My subjects of interest:
queries = ["artificial+intelligence", "machine+learning", "deep+learning"]
# Defining youtube_dl object:
ydl = youtube_dl.YoutubeDL({"ignoreerrors": True})
# Starting the list where we will store the collected data:
results = []
# Collecting data for each query:
for query in queries:
    r = ydl.extract_info("ytsearchdate40:{}".format(query), download=False)
    results += r['entries']
# Out:
# [download] Downloading playlist: artificial+intelligence
# [youtube:search:date] query "artificial+intelligence": Downloading page 1
# [youtube:search:date] query "artificial+intelligence": Downloading page 2
# [youtube:search:date] playlist artificial+intelligence: Downloading 40 videos
# [download] Downloading video 1 of 40
# [youtube] 0Pb3gQ3MoQw: Downloading webpage
# [youtube] 0Pb3gQ3MoQw: Downloading MPD manifest
# [download] Downloading video 2 of 40
# [youtube] 0fpSndBPQZc: Downloading webpage
# [youtube] 0fpSndBPQZc: Downloading MPD manifest
# [download] Downloading video 3 of 40
# [youtube] p3pJMH2rv6w: Downloading webpage
# [youtube] p3pJMH2rv6w: Downloading MPD manifest
# [download] Downloading video 4 of 40
# [youtube] u-8ccBP8za0: Downloading webpage
# [youtube] u-8ccBP8za0: Downloading MPD manifest
# [download] Downloading video 5 of 40
# [youtube] LbfWkj-KMPc: Downloading webpage
# [youtube] LbfWkj-KMPc: Downloading MPD manifest
# [download] Downloading video 6 of 40
# [youtube] SEk3FR6BcPY: Downloading webpage
# [download] Downloading video 7 of 40
# [youtube] WCqyj8-I7gM: Downloading webpage
# [youtube] WCqyj8-I7gM: Downloading MPD manifest
# [download] Downloading video 8 of 40
# [youtube] SM_2JWq4c-k: Downloading webpage
# [youtube] SM_2JWq4c-k: Downloading MPD manifest
# [download] Downloading video 9 of 40
# [youtube] 47c1_Vo-uBs: Downloading webpage
# [youtube] 47c1_Vo-uBs: Downloading MPD manifest
# [download] Downloading video 10 of 40
# [youtube] aqU8a2p8gYA: Downloading webpage
# [youtube] aqU8a2p8gYA: Downloading MPD manifest
# [download] Downloading video 11 of 40
# [youtube] xVsH9wH5KQQ: Downloading webpage
# [youtube] xVsH9wH5KQQ: Downloading MPD manifest
# [download] Downloading video 12 of 40
# [youtube] bhWHGvW2BIA: Downloading webpage
# [youtube] bhWHGvW2BIA: Downloading MPD manifest
# [download] Downloading video 13 of 40
# [youtube] lhhpyqZ9O2w: Downloading webpage
# [youtube] lhhpyqZ9O2w: Downloading MPD manifest
# [download] Downloading video 28 of 40
# [youtube] tx85hdRJA0c: Downloading webpage
# [youtube] tx85hdRJA0c: Downloading MPD manifest
# [download] Downloading video 29 of 40
# [youtube] rSgBIJlZM1E: Downloading webpage
# [youtube] rSgBIJlZM1E: Downloading MPD manifest
# [download] Downloading video 30 of 40
# [youtube] R04VltMpFzg: Downloading webpage
# [youtube] R04VltMpFzg: Downloading MPD manifest
# [download] Downloading video 31 of 40
# [youtube] 7MceDfpnP8k: Downloading webpage
# [download] Downloading video 32 of 40
# [youtube] -Kp061BMxXw: Downloading webpage
# [youtube] -Kp061BMxXw: Downloading MPD manifest
# [download] Downloading video 33 of 40
# [youtube] k_hUdZJNzkU: Downloading webpage
# [download] Downloading video 34 of 40
# [youtube] WTIx7woJFC8: Downloading webpage
# [youtube] WTIx7woJFC8: Downloading MPD manifest
# [download] Downloading video 35 of 40
# [youtube] gbIvB-jvNKM: Downloading webpage
# [youtube] gbIvB-jvNKM: Downloading MPD manifest
# [download] Downloading video 36 of 40
# [youtube] -D0QJjm7s_Q: Downloading webpage
# [youtube] -D0QJjm7s_Q: Downloading MPD manifest
# [download] Downloading video 37 of 40
# [youtube] r6YVHw9eQJ0: Downloading webpage
# [download] Downloading video 38 of 40
# [youtube] kmXPA3xyxiQ: Downloading webpage
# [download] Downloading video 39 of 40
# [youtube] -gq5YyOV1-0: Downloading webpage
# [youtube] -gq5YyOV1-0: Downloading MPD manifest
# [download] Downloading video 40 of 40
# [youtube] NBssx3aWG0I: Downloading webpage
# [youtube] NBssx3aWG0I: Downloading MPD manifest
# [download] Finished downloading playlist: deep+learning

# %%
# FUNCTIONS WHICH TRANSFORM THE FEATURES =========================================================================
def categ(x):
    if (x==['Autos & Vehicles'] or x==['Gaming'] or x==['Comedy'] or
        x==['Sports'] or x==['Pets & Animals'] or x==['Music']): return 0
    elif (x==['Film & Animation'] or x==['Howto & Style']): return 1
    elif (x==['People & Blogs'] or x==['Entertainment']): return 2
    elif x==['Education']: return 3
    elif x==['Science & Technology']: return 4
    elif x==['News & Politics']: return 5
    elif x==['Nonprofits & Activism']: return 6
    else: return 0

def durat(x):
    t = x/60
    if t<=30: return 0
    elif t>30 and t<=70: return 1
    else: return 2

def view(data):
    if 'view_count' in data.keys():
        x = data['view_count']
        if x<=50: return 0
        elif x>50 and x<=1e3: return 1
        elif x>1e3 and x<=1e5: return 2
        else: return 3
    else: return 0
    
def ch_appeal(channel_name):
    list_3 = ['study','mit ','lex ','amini','proj','brunton']
    list_2 = ['tedx','stanford','marr','youtube','online']
    list_1 = ['school','sci','lab','google','krish','course']

    l3 = [True for word in list_3 if word in channel_name]
    l2 = [True for word in list_2 if word in channel_name]
    l1 = [True for word in list_1 if word in channel_name]
    if any(l3): return 3
    elif any(l2): return 2
    elif any(l1): return 1
    else: return 0
    
def like_ra(data):
    if (('like_count' in data.keys()) & ('dislike_count' in data.keys())):
        if data['like_count']==0: return 1
        else:
            ratio = data['dislike_count']/data['like_count']
            if ratio>0.1: return 0
            else: return 1
    else: return 0
    
# FUNCTION WHICH RETURNS THE FINAL DATASET ======================================================================
def compute_features(data):
    """Creates the same features which we used to train the models. """
    
    categories     = categ(data['categories'])
    duration       = durat(data['duration'])
    views          = view(data)
    channel_appeal = ch_appeal(data['uploader'].lower())
    like_ratio     = like_ra(data)
    title          = data['title']

    features = dict()

    features['categ']          = categories
    features['duration']       = duration
    features['views']          = views
    features['like_ratio']     = like_ratio
    features['channel_appeal'] = channel_appeal
    features['title']          = title

    vectorized_title = title_vec.transform([title])

    feats=csr_matrix(np.array([features['categ'],features['duration'],features['views'],features['like_ratio'],features['channel_appeal']]))
    feature_array = hstack([feats, vectorized_title])
    return feature_array

# %% [markdown]
# ## Evaluating models performances on new data

# %%
# FUNCTIONS WHICH RETURN THE PREDICTIONS ===========================================================
def compute_prediction(data,w_lr,w_rf,w_lgbm):
    """Computes the scores of the new videos. """
    if data is None:
        return 0
    
    feature_array = compute_features(data)
    #print(feature_array)

    if feature_array is None:
        return 0


    p_rf   = clf_rf.predict_proba(feature_array)[0][1]
    p_lr   = clf_lr.predict_proba(feature_array)[0][1]
    p_lgbm = clf_lgbm.predict_proba(feature_array)[0][1]
    p = w_lr*p_lr + w_rf*p_rf + w_lgbm*p_lgbm
    return p

def predictions_list(w_lr,w_rf,w_lgbm):
    predictions = pd.DataFrame(columns=['title', 'score'])
    for i in results:
        row = {'title':i['title'], 'score':compute_prediction(i,w_lr,w_rf,w_lgbm)}
        predictions = predictions.append(row,ignore_index=True)
    predictions = predictions.drop_duplicates(subset=['title','score'], keep='first')
    return predictions

pd.options.display.max_colwidth = 120

# %% [markdown]
# ### Random Forest predictions

# %%
w_lr=0; w_rf=1; w_lgbm=0;

rf_predictions = predictions_list(w_lr,w_rf,w_lgbm).drop_duplicates(subset=['title','score'],keep='first')
rf_predictions_sorted = rf_predictions.sort_values(by='score',ascending=False)
rf_predictions_sorted[:20]
# Out:
# /Users/nataliatenoriomaia/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:739: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
#                                                                                                   title  \
# 105                                 Image Colorization Using GANs | Deep Learning | TensorFlow | Python
# 84                                                                    Deep Learning Meets Sparse Coding
# 110    Cancer Detection Using Deep Learning | Deep Learning Projects | Deep Learning Training | Edureka
# 112   The Dimpled Manifold Model of Adversarial Examples in Machine Learning (Research Paper Explained)
# 108                          Uncertainty Estimation for Object Detection Using Deep Learning Approaches
# 56                                      Dive into Deep Learning: Coding Session #6 GANs (Americas/EMEA)
# 57                                               Dive into Deep Learning: Coding Session #6 GANs (APAC)
# 117                Sharing My Time Table And Efficient Strategy To Learn Machine Learning In Quick Time
# 111                                   plant diseases detection using image processing and deep learning
# 33                              The Race for Artificial Intelligence | Vice Documentary CyberWar Series
# 90                                         Object detection using deep learning dataset cctv road video
# 118  Lecture on "Simple, Fast and Practical Uncertainty Estimation in Deep Learning" by Jishnu Mukhoti.
# 107                 Smart Voting System Through Face Recognition code using python and machine learning
# 53                                                  Introduction to Machine Learning (practical issues)
# 103                                                     Deep Learning | Basic Building Blocks  of CNN 1
# 102                                                     Day-12 # Deep Learning Bootcamp - RNN Intuition
# 29                                       Lecture 17:Generate and Test search in Artificial Intelligence
# 1                                   B.Sc. Artificial Intelligence at Deggendorf Institute of Technology
# 58                          Les clés du Machine Learning en Product Management - Ludovic Peran @ Google
# 96         Diabetes Classification using ML and DL algorithm | Data Science Tutorial | Machine Learning
#
#         score
# 105  0.630703
# 84   0.572992
# 110  0.563592
# 112  0.554787
# 108  0.547998
# 56   0.543161
# 57   0.537145
# 117  0.525612
# 111  0.522563
# 33   0.518318
# 90   0.506052
# 118  0.500268
# 107  0.497551
# 53   0.490859
# 103  0.487288
# 102  0.486558
# 29   0.484649
# 1    0.479319
# 58   0.477113
# 96   0.476034

# %%
rf_predictions_sorted[-10:]
# Out:
#                                                                                                    title  \
# 6                                                                                artificial intelligence
# 64                Wafer Health Predictive Modeling - End to End Machine Learning Project 01 - Urdu/Hindi
# 15   Artificial Intelligence - What is it and how far can it go in Hindi Urduارٹی فیشل انٹلی جنس ۔کیا ہے
# 32                                                  Artificial Intelligence PowerPoint Templates Designs
# 0                                                                           Artificial Intelligence Jerk
# 115                                                                             What is Machine Learning
# 35         ai artificial intelligence. artificial intelligence course. artificial intelligence tutorial.
# 49                                                                             machine learning revise3d
# 4                                                       Fundamentals of Artificial Intelligence in Hindi
# 36    Artificial Intelligence Machine Learning Deep Learning Ppt Powerpoint Presentation Slide Templates
#
#         score
# 6    0.333709
# 64   0.327973
# 15   0.322980
# 32   0.289827
# 0    0.284792
# 115  0.281476
# 35   0.277768
# 49   0.270784
# 4    0.269062
# 36   0.252998

# %% [markdown]
# ### LGBM predictions

# %%
w_lr=0; w_rf=0; w_lgbm=1;

lgbm_predictions = predictions_list(w_lr,w_rf,w_lgbm).drop_duplicates(subset=['title','score'],keep='first')
lgbm_predictions_sorted = lgbm_predictions.sort_values(by='score',ascending=False)
lgbm_predictions_sorted[:20]
# Out:
# /Users/nataliatenoriomaia/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:739: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
#                                                                                                     title  \
# 110      Cancer Detection Using Deep Learning | Deep Learning Projects | Deep Learning Training | Edureka
# 84                                                                      Deep Learning Meets Sparse Coding
# 105                                   Image Colorization Using GANs | Deep Learning | TensorFlow | Python
# 56                                        Dive into Deep Learning: Coding Session #6 GANs (Americas/EMEA)
# 108                            Uncertainty Estimation for Object Detection Using Deep Learning Approaches
# 118    Lecture on "Simple, Fast and Practical Uncertainty Estimation in Deep Learning" by Jishnu Mukhoti.
# 26          Leti Innovation Days 2021 - #Semiconductors, #Innovation Engine for #Artificial #Intelligence
# 57                                                 Dive into Deep Learning: Coding Session #6 GANs (APAC)
# 112     The Dimpled Manifold Model of Adversarial Examples in Machine Learning (Research Paper Explained)
# 33                                The Race for Artificial Intelligence | Vice Documentary CyberWar Series
# 102                                                       Day-12 # Deep Learning Bootcamp - RNN Intuition
# 90                                           Object detection using deep learning dataset cctv road video
# 40     Modularity in Reinforcement Learning via Algorithmic Independence in Credit Assignment (ICML 2021)
# 94                                     Tips for Passing the AWS Certified Machine Learning Specialty Exam
# 53                                                    Introduction to Machine Learning (practical issues)
# 29                                         Lecture 17:Generate and Test search in Artificial Intelligence
# 104  INDIAai Conversations|How ISI Kolkata researchers developed Deep Learning tool for COVID19 screening
# 117                  Sharing My Time Table And Efficient Strategy To Learn Machine Learning In Quick Time
# 114                        Train Custom Question Answering NLP Model | NLP | Data Science | Deep Learning
# 23                                 #ONPASSIVE BLOG VIDEO : Artificial Intelligence and the Creative World
#
#         score
# 110  0.878264
# 84   0.836550
# 105  0.808218
# 56   0.725182
# 108  0.706868
# 118  0.676862
# 26   0.672647
# 57   0.615400
# 112  0.615226
# 33   0.608709
# 102  0.594658
# 90   0.580887
# 40   0.570410
# 94   0.557008
# 53   0.541757
# 29   0.510502
# 104  0.507745
# 117  0.475704
# 114  0.470000
# 23   0.469199

# %%
lgbm_predictions_sorted[-10:]
# Out:
#                                                                                                     title  \
# 64                 Wafer Health Predictive Modeling - End to End Machine Learning Project 01 - Urdu/Hindi
# 28                            IAT PE DXB - Vertical Jump - Flipped Learning - Artificial Intelligence App
# 32                                                   Artificial Intelligence PowerPoint Templates Designs
# 88   Matthias Nowak's Innovative Technical and Creative Exercises 👉 Deep Learning with Issam and Amir ⚽️🔥
# 34                               Įspūdis 19. Dirbtinis intelektas. Impression 19. Artificial Intelligence
# 49                                                                              machine learning revise3d
# 4                                                        Fundamentals of Artificial Intelligence in Hindi
# 19                             Borderless Security - Artificial Intelligence and Machine Learning (AI/ML)
# 115                                                                              What is Machine Learning
# 36     Artificial Intelligence Machine Learning Deep Learning Ppt Powerpoint Presentation Slide Templates
#
#         score
# 64   0.043154
# 28   0.039342
# 32   0.038561
# 88   0.019888
# 34   0.019453
# 49   0.012376
# 4    0.008516
# 19   0.007719
# 115  0.006294
# 36   0.002912

# %% [markdown]
# ### Logistic Regression predictions

# %%
w_lr=1; w_rf=0; w_lgbm=0;

lr_predictions = predictions_list(w_lr,w_rf,w_lgbm).drop_duplicates(subset=['title','score'],keep='first')
lr_predictions_sorted = lr_predictions.sort_values(by='score',ascending=False)
lr_predictions_sorted[:20]
# Out:
# /Users/nataliatenoriomaia/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:739: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
#                                                                                                     title  \
# 110      Cancer Detection Using Deep Learning | Deep Learning Projects | Deep Learning Training | Edureka
# 105                                   Image Colorization Using GANs | Deep Learning | TensorFlow | Python
# 112     The Dimpled Manifold Model of Adversarial Examples in Machine Learning (Research Paper Explained)
# 57                                                 Dive into Deep Learning: Coding Session #6 GANs (APAC)
# 108                            Uncertainty Estimation for Object Detection Using Deep Learning Approaches
# 33                                The Race for Artificial Intelligence | Vice Documentary CyberWar Series
# 111                                     plant diseases detection using image processing and deep learning
# 84                                                                      Deep Learning Meets Sparse Coding
# 56                                        Dive into Deep Learning: Coding Session #6 GANs (Americas/EMEA)
# 26          Leti Innovation Days 2021 - #Semiconductors, #Innovation Engine for #Artificial #Intelligence
# 107                   Smart Voting System Through Face Recognition code using python and machine learning
# 90                                           Object detection using deep learning dataset cctv road video
# 40     Modularity in Reinforcement Learning via Algorithmic Independence in Credit Assignment (ICML 2021)
# 94                                     Tips for Passing the AWS Certified Machine Learning Specialty Exam
# 12                     Dissemination of project From Internet of Thing to Artificial Intelligence (IoTAI)
# 59                                                National Webinar on Machine Learning and Data Analytics
# 20                        Rembrandt’s ‘The Night Watch’ restored with the help of Artificial Intelligence
# 75                      Quantum neural network - Quantum machine learning of graph-structured data Part 2
# 104  INDIAai Conversations|How ISI Kolkata researchers developed Deep Learning tool for COVID19 screening
# 10                          A.ELMEHDI - Investigation of obstacle detection using Artificial Intelligence
#
#         score
# 110  0.725457
# 105  0.706402
# 112  0.651395
# 57   0.634164
# 108  0.630856
# 33   0.623608
# 111  0.613881
# 84   0.571818
# 56   0.557809
# 26   0.552628
# 107  0.532581
# 90   0.505648
# 40   0.503854
# 94   0.495713
# 12   0.482389
# 59   0.479668
# 20   0.472411
# 75   0.464749
# 104  0.460899
# 10   0.453116

# %%
lr_predictions_sorted[-10:]
# Out:
#                                                                                                   title  \
# 52                     What Is Data Science | Data Science vs Machine Learning (Data Science Explained)
# 73                                                                Machine Learning: Dimension Reduction
# 32                                                 Artificial Intelligence PowerPoint Templates Designs
# 19                           Borderless Security - Artificial Intelligence and Machine Learning (AI/ML)
# 115                                                                            What is Machine Learning
# 0                                                                          Artificial Intelligence Jerk
# 35        ai artificial intelligence. artificial intelligence course. artificial intelligence tutorial.
# 36   Artificial Intelligence Machine Learning Deep Learning Ppt Powerpoint Presentation Slide Templates
# 49                                                                            machine learning revise3d
# 4                                                      Fundamentals of Artificial Intelligence in Hindi
#
#         score
# 52   0.145629
# 73   0.144246
# 32   0.129145
# 19   0.128007
# 115  0.122880
# 0    0.112756
# 35   0.097196
# 36   0.094960
# 49   0.090161
# 4    0.085167

# %% [markdown]
# ### Ensemble 1 : 0.3 p_lr + 0.5 p_rf + 0.2 p_lgbm

# %%
w_lr=0.3; w_rf=0.5; w_lgbm=0.2;

e1_predictions = predictions_list(w_lr,w_rf,w_lgbm).drop_duplicates(subset=['title','score'],keep='first')
e1_predictions_sorted = e1_predictions.sort_values(by='score',ascending=False)
e1_predictions_sorted[:20]
# Out:
# /Users/nataliatenoriomaia/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:739: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
#                                                                                                   title  \
# 105                                 Image Colorization Using GANs | Deep Learning | TensorFlow | Python
# 110    Cancer Detection Using Deep Learning | Deep Learning Projects | Deep Learning Training | Edureka
# 84                                                                    Deep Learning Meets Sparse Coding
# 108                          Uncertainty Estimation for Object Detection Using Deep Learning Approaches
# 112   The Dimpled Manifold Model of Adversarial Examples in Machine Learning (Research Paper Explained)
# 56                                      Dive into Deep Learning: Coding Session #6 GANs (Americas/EMEA)
# 57                                               Dive into Deep Learning: Coding Session #6 GANs (APAC)
# 33                              The Race for Artificial Intelligence | Vice Documentary CyberWar Series
# 111                                   plant diseases detection using image processing and deep learning
# 90                                         Object detection using deep learning dataset cctv road video
# 26        Leti Innovation Days 2021 - #Semiconductors, #Innovation Engine for #Artificial #Intelligence
# 118  Lecture on "Simple, Fast and Practical Uncertainty Estimation in Deep Learning" by Jishnu Mukhoti.
# 40   Modularity in Reinforcement Learning via Algorithmic Independence in Credit Assignment (ICML 2021)
# 107                 Smart Voting System Through Face Recognition code using python and machine learning
# 117                Sharing My Time Table And Efficient Strategy To Learn Machine Learning In Quick Time
# 94                                   Tips for Passing the AWS Certified Machine Learning Specialty Exam
# 53                                                  Introduction to Machine Learning (practical issues)
# 20                      Rembrandt’s ‘The Night Watch’ restored with the help of Artificial Intelligence
# 102                                                     Day-12 # Deep Learning Bootcamp - RNN Intuition
# 10                        A.ELMEHDI - Investigation of obstacle detection using Artificial Intelligence
#
#         score
# 105  0.688916
# 110  0.675086
# 84   0.625352
# 108  0.604629
# 112  0.595857
# 56   0.583960
# 57   0.581902
# 33   0.567983
# 111  0.527998
# 90   0.520898
# 26   0.517870
# 118  0.513690
# 40   0.501981
# 107  0.497424
# 117  0.487872
# 94   0.482417
# 53   0.474738
# 20   0.461970
# 102  0.456163
# 10   0.453025

# %%
e1_predictions_sorted[-10:]
# Out:
#                                                                                                    title  \
# 73                                                                 Machine Learning: Dimension Reduction
# 15   Artificial Intelligence - What is it and how far can it go in Hindi Urduارٹی فیشل انٹلی جنس ۔کیا ہے
# 19                            Borderless Security - Artificial Intelligence and Machine Learning (AI/ML)
# 35         ai artificial intelligence. artificial intelligence course. artificial intelligence tutorial.
# 32                                                  Artificial Intelligence PowerPoint Templates Designs
# 0                                                                           Artificial Intelligence Jerk
# 115                                                                             What is Machine Learning
# 49                                                                             machine learning revise3d
# 4                                                       Fundamentals of Artificial Intelligence in Hindi
# 36    Artificial Intelligence Machine Learning Deep Learning Ppt Powerpoint Presentation Slide Templates
#
#         score
# 73   0.237592
# 15   0.227669
# 19   0.218226
# 35   0.202702
# 32   0.191369
# 0    0.188984
# 115  0.178861
# 49   0.164915
# 4    0.161784
# 36   0.155569

# %% [markdown]
# ### Ensemble 2 : 0.4 p_lr + 0.6 p_lgbm

# %%
w_lr=0.4; w_rf=0; w_lgbm=0.6;

e2_predictions = predictions_list(w_lr,w_rf,w_lgbm).drop_duplicates(subset=['title','score'],keep='first')
e2_predictions_sorted = e2_predictions.sort_values(by='score',ascending=False)
e2_predictions_sorted[:20]
# Out:
# /Users/nataliatenoriomaia/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:739: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
#                                                                                                     title  \
# 110      Cancer Detection Using Deep Learning | Deep Learning Projects | Deep Learning Training | Edureka
# 105                                   Image Colorization Using GANs | Deep Learning | TensorFlow | Python
# 84                                                                      Deep Learning Meets Sparse Coding
# 108                            Uncertainty Estimation for Object Detection Using Deep Learning Approaches
# 56                                        Dive into Deep Learning: Coding Session #6 GANs (Americas/EMEA)
# 112     The Dimpled Manifold Model of Adversarial Examples in Machine Learning (Research Paper Explained)
# 26          Leti Innovation Days 2021 - #Semiconductors, #Innovation Engine for #Artificial #Intelligence
# 57                                                 Dive into Deep Learning: Coding Session #6 GANs (APAC)
# 33                                The Race for Artificial Intelligence | Vice Documentary CyberWar Series
# 118    Lecture on "Simple, Fast and Practical Uncertainty Estimation in Deep Learning" by Jishnu Mukhoti.
# 90                                           Object detection using deep learning dataset cctv road video
# 40     Modularity in Reinforcement Learning via Algorithmic Independence in Credit Assignment (ICML 2021)
# 94                                     Tips for Passing the AWS Certified Machine Learning Specialty Exam
# 111                                     plant diseases detection using image processing and deep learning
# 104  INDIAai Conversations|How ISI Kolkata researchers developed Deep Learning tool for COVID19 screening
# 53                                                    Introduction to Machine Learning (practical issues)
# 102                                                       Day-12 # Deep Learning Bootcamp - RNN Intuition
# 107                   Smart Voting System Through Face Recognition code using python and machine learning
# 117                  Sharing My Time Table And Efficient Strategy To Learn Machine Learning In Quick Time
# 20                        Rembrandt’s ‘The Night Watch’ restored with the help of Artificial Intelligence
#
#         score
# 110  0.817141
# 105  0.767492
# 84   0.730657
# 108  0.676463
# 56   0.658233
# 112  0.629694
# 26   0.624640
# 57   0.622906
# 33   0.614668
# 118  0.577029
# 90   0.550791
# 40   0.543787
# 94   0.532490
# 111  0.493209
# 104  0.489006
# 53   0.486330
# 102  0.482065
# 107  0.479654
# 117  0.458656
# 20   0.452626

# %%
e2_predictions_sorted[-10:]
# Out:
#                                                                                                    title  \
# 28                           IAT PE DXB - Vertical Jump - Flipped Learning - Artificial Intelligence App
# 15   Artificial Intelligence - What is it and how far can it go in Hindi Urduارٹی فیشل انٹلی جنس ۔کیا ہے
# 73                                                                 Machine Learning: Dimension Reduction
# 0                                                                           Artificial Intelligence Jerk
# 32                                                  Artificial Intelligence PowerPoint Templates Designs
# 19                            Borderless Security - Artificial Intelligence and Machine Learning (AI/ML)
# 115                                                                             What is Machine Learning
# 49                                                                             machine learning revise3d
# 36    Artificial Intelligence Machine Learning Deep Learning Ppt Powerpoint Presentation Slide Templates
# 4                                                       Fundamentals of Artificial Intelligence in Hindi
#
#         score
# 28   0.113252
# 15   0.112013
# 73   0.108005
# 0    0.083387
# 32   0.074795
# 19   0.055834
# 115  0.052928
# 49   0.043490
# 36   0.039731
# 4    0.039176

# %% [markdown]
# ### Ensemble 3 : 0.1p_rf + 0.9p_lgbm

# %%
w_lr=0; w_rf=0.1; w_lgbm=0.9;

e3_predictions = predictions_list(w_lr,w_rf,w_lgbm).drop_duplicates(subset=['title','score'],keep='first')
e3_predictions_sorted = e3_predictions.sort_values(by='score',ascending=False)
e3_predictions_sorted[:20]
# Out:
# /Users/nataliatenoriomaia/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:739: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
#                                                                                                     title  \
# 110      Cancer Detection Using Deep Learning | Deep Learning Projects | Deep Learning Training | Edureka
# 84                                                                      Deep Learning Meets Sparse Coding
# 105                                   Image Colorization Using GANs | Deep Learning | TensorFlow | Python
# 56                                        Dive into Deep Learning: Coding Session #6 GANs (Americas/EMEA)
# 108                            Uncertainty Estimation for Object Detection Using Deep Learning Approaches
# 118    Lecture on "Simple, Fast and Practical Uncertainty Estimation in Deep Learning" by Jishnu Mukhoti.
# 26          Leti Innovation Days 2021 - #Semiconductors, #Innovation Engine for #Artificial #Intelligence
# 112     The Dimpled Manifold Model of Adversarial Examples in Machine Learning (Research Paper Explained)
# 57                                                 Dive into Deep Learning: Coding Session #6 GANs (APAC)
# 33                                The Race for Artificial Intelligence | Vice Documentary CyberWar Series
# 102                                                       Day-12 # Deep Learning Bootcamp - RNN Intuition
# 90                                           Object detection using deep learning dataset cctv road video
# 40     Modularity in Reinforcement Learning via Algorithmic Independence in Credit Assignment (ICML 2021)
# 94                                     Tips for Passing the AWS Certified Machine Learning Specialty Exam
# 53                                                    Introduction to Machine Learning (practical issues)
# 29                                         Lecture 17:Generate and Test search in Artificial Intelligence
# 104  INDIAai Conversations|How ISI Kolkata researchers developed Deep Learning tool for COVID19 screening
# 117                  Sharing My Time Table And Efficient Strategy To Learn Machine Learning In Quick Time
# 114                        Train Custom Question Answering NLP Model | NLP | Data Science | Deep Learning
# 96           Diabetes Classification using ML and DL algorithm | Data Science Tutorial | Machine Learning
#
#         score
# 110  0.846796
# 84   0.810194
# 105  0.790467
# 56   0.706980
# 108  0.690981
# 118  0.659202
# 26   0.648893
# 112  0.609182
# 57   0.607575
# 33   0.599670
# 102  0.583848
# 90   0.573403
# 40   0.560717
# 94   0.545767
# 53   0.536667
# 29   0.507917
# 104  0.497806
# 117  0.480695
# 114  0.470311
# 96   0.468801

# %%
e3_predictions_sorted[-10:]
# Out:
#                                                                                                     title  \
# 64                 Wafer Health Predictive Modeling - End to End Machine Learning Project 01 - Urdu/Hindi
# 28                            IAT PE DXB - Vertical Jump - Flipped Learning - Artificial Intelligence App
# 32                                                   Artificial Intelligence PowerPoint Templates Designs
# 88   Matthias Nowak's Innovative Technical and Creative Exercises 👉 Deep Learning with Issam and Amir ⚽️🔥
# 34                               Įspūdis 19. Dirbtinis intelektas. Impression 19. Artificial Intelligence
# 19                             Borderless Security - Artificial Intelligence and Machine Learning (AI/ML)
# 49                                                                              machine learning revise3d
# 4                                                        Fundamentals of Artificial Intelligence in Hindi
# 115                                                                              What is Machine Learning
# 36     Artificial Intelligence Machine Learning Deep Learning Ppt Powerpoint Presentation Slide Templates
#
#         score
# 64   0.071636
# 28   0.070900
# 32   0.063688
# 88   0.054201
# 34   0.052998
# 19   0.042603
# 49   0.038217
# 4    0.034570
# 115  0.033812
# 36   0.027920

# %% [markdown]
# ## Conclusion
#
# When we compare the three classifiers, we see that LightGBM is by far the most confident, i.e., it can assign very high or very low scores to the new videos. The second most confident is Logistic Regression, while Random Forest assigns values that range from only 0.3 to 0.6, approximately.
#
# The predictor that performs the best is Ensemble 3, because it combines the confidence of LightGBM with a little bit of doubt from Random Forest. This combination, which assigns LightGBM's prediction a weight of 0.9 and Random Forest's a weight of 0.1, gives me the most satisfactory  result for the most appealing Youtube videos about artificial intelligence, machine learning and deep learning, posted in recent times.
#
# Therefore, we will use
#
# $$p = 0.1p_{rf}+0.9p_{lgbm}$$
#
# as our predictor in the web application for this recommender, which can be accessed at this [link](https://stormy-lake-83008.herokuapp.com/).
